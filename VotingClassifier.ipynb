# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("oasis_longitudinal_demographics.csv")

# %%
df
# Out:
#                        MRI ID        Group  Visit  MR Delay M/F Hand  Age  \
# 0    OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87
# 1    OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88
# 2    OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75
# 3    OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76
# 4    OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80
# ..         ...            ...          ...    ...       ...  ..  ...  ...
# 368  OAS2_0185  OAS2_0185_MR2     Demented      2       842   M    R   82
# 369  OAS2_0185  OAS2_0185_MR3     Demented      3      2297   M    R   86
# 370  OAS2_0186  OAS2_0186_MR1  Nondemented      1         0   F    R   61
# 371  OAS2_0186  OAS2_0186_MR2  Nondemented      2       763   F    R   63
# 372  OAS2_0186  OAS2_0186_MR3  Nondemented      3      1608   F    R   65
#
#      EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0      14  2.0  27.0  0.0  1987  0.696  0.883
# 1      14  2.0  30.0  0.0  2004  0.681  0.876
# 2      12  NaN  23.0  0.5  1678  0.736  1.046
# 3      12  NaN  28.0  0.5  1738  0.713  1.010
# 4      12  NaN  22.0  0.5  1698  0.701  1.034
# ..    ...  ...   ...  ...   ...    ...    ...
# 368    16  1.0  28.0  0.5  1693  0.694  1.037
# 369    16  1.0  26.0  0.5  1688  0.675  1.040
# 370    13  2.0  30.0  0.0  1319  0.801  1.331
# 371    13  2.0  30.0  0.0  1327  0.796  1.323
# 372    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0             373 non-null    object
#  1   MRI ID    373 non-null    object
#  2   Group     373 non-null    object
#  3   Visit     373 non-null    int64
#  4   MR Delay  373 non-null    int64
#  5   M/F       373 non-null    object
#  6   Hand      373 non-null    object
#  7   Age       373 non-null    int64
#  8   EDUC      373 non-null    int64
#  9   SES       354 non-null    float64
#  10  MMSE      371 non-null    float64
#  11  CDR       373 non-null    float64
#  12  eTIV      373 non-null    int64
#  13  nWBV      373 non-null    float64
#  14  ASF       373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
df['Group'].value_counts()
# Out:
# Nondemented    190
# Demented       146
# Converted       37
# Name: Group, dtype: int64

# %%
df.corr()
# Out:
#              Visit  MR Delay       Age      EDUC       SES      MMSE  \
# Visit     1.000000  0.920009  0.183213  0.024615 -0.051622 -0.029078
# MR Delay  0.920009  1.000000  0.205357  0.051630 -0.030813  0.065844
# Age       0.183213  0.205357  1.000000 -0.027886 -0.046857  0.055612
# EDUC      0.024615  0.051630 -0.027886  1.000000 -0.722647  0.194884
# SES      -0.051622 -0.030813 -0.046857 -0.722647  1.000000 -0.149219
# MMSE     -0.029078  0.065844  0.055612  0.194884 -0.149219  1.000000
# CDR       0.002325 -0.062915 -0.026257 -0.153121  0.076160 -0.686519
# eTIV      0.117428  0.119624  0.042348  0.257015 -0.261575 -0.032084
# nWBV     -0.126682 -0.105586 -0.518359 -0.012200  0.090095  0.341912
# ASF      -0.120399 -0.123545 -0.035067 -0.241752  0.255576  0.040052
#
#                CDR      eTIV      nWBV       ASF
# Visit     0.002325  0.117428 -0.126682 -0.120399
# MR Delay -0.062915  0.119624 -0.105586 -0.123545
# Age      -0.026257  0.042348 -0.518359 -0.035067
# EDUC     -0.153121  0.257015 -0.012200 -0.241752
# SES       0.076160 -0.261575  0.090095  0.255576
# MMSE     -0.686519 -0.032084  0.341912  0.040052
# CDR       1.000000  0.022819 -0.344819 -0.029340
# eTIV      0.022819  1.000000 -0.210122 -0.988877
# nWBV     -0.344819 -0.210122  1.000000  0.213476
# ASF      -0.029340 -0.988877  0.213476  1.000000

# %%
num_df = df.select_dtypes(exclude = ['object'])

# %%
df["Visit"].value_counts()
# Out:
# 1    150
# 2    144
# 3     58
# 4     15
# 5      6
# Name: Visit, dtype: int64

# %%
df.shape
# Out:
# (373, 15)

# %%
from sklearn.preprocessing import LabelEncoder
encoded = ls.fit(df['Group'])
fin_encoded = ls.transform(df['Group'])
df['Group'] = fin_encoded

# %%
df['Group'].value_counts()
# Out:
# 2    190
# 1    146
# 0     37
# Name: Group, dtype: int64

# %%
from scipy import stats

for column in num_df.columns:
    print(stats.pointbiserialr(df['Group'], num_df[column]))
# Out:
# PointbiserialrResult(correlation=0.048434342806104626, pvalue=0.3509075067314852)
# PointbiserialrResult(correlation=0.049261865195138144, pvalue=0.34272869383113064)
# PointbiserialrResult(correlation=-0.049267479533229463, pvalue=0.3426736223338603)
# PointbiserialrResult(correlation=0.1006060768050919, pvalue=0.05220580130171562)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0d621478dc48> in <module>
#       2
#       3 for column in num_df.columns:
# ----> 4     print(stats.pointbiserialr(df['Group'], num_df[column]))
#
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py in pointbiserialr(x, y)
#    4323
#    4324     """
# -> 4325     rpb, prob = pearsonr(x, y)
#    4326     return PointbiserialrResult(rpb, prob)
#    4327
#
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3866     # [-5e210, 5e210, 3e200, -3e200]
#    3867     normxm = linalg.norm(xm)
# -> 3868     normym = linalg.norm(ym)
#    3869
#    3870     threshold = 1e-13
#
# C:\Anaconda\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# C:\Anaconda\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     601     a = asarray(a, dtype=dtype, order=order)
#     602     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603         raise ValueError(
#     604             "array must not contain infs or NaNs")
#     605     return a
#
# ValueError: array must not contain infs or NaNs

# %%
df.corr()
# Out:
#              Group     Visit  MR Delay       Age      EDUC       SES  \
# Group     1.000000  0.048434  0.049262 -0.049267  0.100606  0.053845
# Visit     0.048434  1.000000  0.920009  0.183213  0.024615 -0.051622
# MR Delay  0.049262  0.920009  1.000000  0.205357  0.051630 -0.030813
# Age      -0.049267  0.183213  0.205357  1.000000 -0.027886 -0.046857
# EDUC      0.100606  0.024615  0.051630 -0.027886  1.000000 -0.722647
# SES       0.053845 -0.051622 -0.030813 -0.046857 -0.722647  1.000000
# MMSE      0.340257 -0.029078  0.065844  0.055612  0.194884 -0.149219
# CDR      -0.572518  0.002325 -0.062915 -0.026257 -0.153121  0.076160
# eTIV      0.056693  0.117428  0.119624  0.042348  0.257015 -0.261575
# nWBV      0.258093 -0.126682 -0.105586 -0.518359 -0.012200  0.090095
# ASF      -0.042848 -0.120399 -0.123545 -0.035067 -0.241752  0.255576
#
#               MMSE       CDR      eTIV      nWBV       ASF
# Group     0.340257 -0.572518  0.056693  0.258093 -0.042848
# Visit    -0.029078  0.002325  0.117428 -0.126682 -0.120399
# MR Delay  0.065844 -0.062915  0.119624 -0.105586 -0.123545
# Age       0.055612 -0.026257  0.042348 -0.518359 -0.035067
# EDUC      0.194884 -0.153121  0.257015 -0.012200 -0.241752
# SES      -0.149219  0.076160 -0.261575  0.090095  0.255576
# MMSE      1.000000 -0.686519 -0.032084  0.341912  0.040052
# CDR      -0.686519  1.000000  0.022819 -0.344819 -0.029340
# eTIV     -0.032084  0.022819  1.000000 -0.210122 -0.988877
# nWBV      0.341912 -0.344819 -0.210122  1.000000  0.213476
# ASF       0.040052 -0.029340 -0.988877  0.213476  1.000000

# %%
df.isnull().sum()
# Out:
#              0
# MRI ID       0
# Group        0
# Visit        0
# MR Delay     0
# M/F          0
# Hand         0
# Age          0
# EDUC         0
# SES         19
# MMSE         2
# CDR          0
# eTIV         0
# nWBV         0
# ASF          0
# dtype: int64

# %%
df['MMSE'].value_counts()
# Out:
# 30.0    114
# 29.0     91
# 28.0     45
# 27.0     32
# 26.0     20
# 25.0     12
# 21.0     11
# 23.0     11
# 22.0      7
# 20.0      7
# 17.0      5
# 24.0      4
# 16.0      3
# 19.0      3
# 15.0      2
# 18.0      2
# 7.0       1
# 4.0       1
# Name: MMSE, dtype: int64

# %%
df['SES'].value_counts()
# Out:
# 2.0    103
# 1.0     88
# 3.0     82
# 4.0     74
# 5.0      7
# Name: SES, dtype: int64

# %%
df['EDUC'].value_counts()
# Out:
# 12    103
# 16     81
# 18     64
# 14     33
# 13     27
# 15     17
# 20     13
# 11     11
# 8       9
# 17      9
# 6       3
# 23      3
# Name: EDUC, dtype: int64

# %%
df['EDUC']
